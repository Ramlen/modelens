# %%
import modelens
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import modelens
#
# File ~/Desktop/modelens/modelens/__init__.py:3
#       1 """modelens — ML model diagnostics lens for binary classification."""
# ----> 3 from modelens.diagnostics import plot_model_diagnostics
#       4 from modelens.diagnostics import (
#       5     plot_loss_curve,
#       6     plot_score_distribution,
#    (...)      9     plot_pr_curves,
#      10 )
#      12 __version__ = "0.1.0"
#
# ModuleNotFoundError: No module named 'modelens.diagnostics'
